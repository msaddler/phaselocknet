# %%
import os
import sys
import copy
import glob
import h5py
import json
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import IPython.display as ipd

import util_figures
import util_signal
import util_cochlea
import util_network
# Out:
# 2024-08-13 04:12:11.093541: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-13 04:12:13.573388: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
"""
Specify model directory and load config / architecture
"""

dir_model = "models/spkr_word_recognition/simplified_IHC3000/arch0_0000"

fn_config = os.path.join(dir_model, "config.json")
fn_arch = os.path.join(dir_model, "arch.json")
fn_ckpt = os.path.join(dir_model, "ckpt_BEST")

with open(fn_config, "r") as f_config:
    CONFIG = json.load(f_config)
with open(fn_arch, "r") as f_arch:
    list_layer_dict = json.load(f_arch)
n_classes_dict = CONFIG["n_classes_dict"]

if CONFIG.get("kwargs_cochlea", {}):
    sr = CONFIG["kwargs_cochlea"]["sr_input"]
    if "localization" in dir_model:
        input_shape = [int(1.3 * sr), 2] # 1.3-second binaural input for localization model
    else:
        input_shape = [int(2 * sr)] # 2-second monaural input for word + voice recognition model
else:
    if "localization" in dir_model:
        input_shape = [50, 10000, 3, 2] # Pre-generated nervegram (50 freq channels, 1-second at 10 kHz, 3 spont rates, binaural)
    else:
        input_shape = [50, 20000, 3] # Pre-generated nervegram (50 freq channels, 2-seconds at 10 kHz, 3 spont rates, monaural)

print(f"Model input shape: {input_shape}")
print(f"Model output shape(s): {n_classes_dict}")
# Out:
# Model input shape: [40000]
# Model output shape(s): {'label_speaker_int': 433, 'label_word_int': 794}

# %%
CONFIG["kwargs_cochlea"]["kwargs_autocorrelation_correlogram"] = {
    "dur_frame": 0.05,
    "overlap": 0.5,
    "one_sided": True,
    "concat_axis": None,
}

# %%
"""
Build TensorFlow model object and load pre-trained weights
"""
import importlib
importlib.reload(util_cochlea)

def model_io_function(x):
    y = x
    if CONFIG.get("kwargs_cochlea", {}):
        if "label_loc_int" in n_classes_dict:
            msg = "expected [batch, freq, time, spont, channel=2] or [batch, time, channel=2]"
            assert (len(y.shape) in [3, 5]) and (y.shape[-1] == 2), msg
            y0, _ = util_cochlea.cochlea(y[..., 0], **copy.deepcopy(CONFIG["kwargs_cochlea"]))
            y1, _ = util_cochlea.cochlea(y[..., 1], **copy.deepcopy(CONFIG["kwargs_cochlea"]))
            y = tf.concat([y0, y1], axis=-1)
            if y.shape[2] > nervegram_slice_length:
                y = util_cochlea.random_slice(
                    y,
                    slice_length=nervegram_slice_length,
                    axis=2, # Time axis
                    buffer=500)
        else:
            y, _ = util_cochlea.cochlea(y, **copy.deepcopy(CONFIG["kwargs_cochlea"]))
    # y, _ = util_network.build_network(y, list_layer_dict, n_classes_dict=n_classes_dict)
    return y

inputs = tf.keras.Input(shape=input_shape, batch_size=None, dtype=tf.float32)
model = tf.keras.Model(inputs=inputs, outputs=model_io_function(inputs))
# model.load_weights(fn_ckpt)
model.summary()
# Out:
# [cochlea] converting audio to subbands using fir_gammatone_filterbank
# [cochlea] half-wave rectified subbands
# [tf_fir_resample] interpreted `tensor_input.shape` as [batch, freq=50, time=40000]
# [tf_fir_resample] `kwargs_fir_lowpass_filter`: {'cutoff': 3000, 'fir_dur': 0.05, 'ihc_filter': True, 'order': 7}
# [fir_lowpass_filter] sr_filt = 20000.0 Hz
# [fir_lowpass_filter] numtaps = 1001 samples
# [fir_lowpass_filter] fir_dur = 0.05 seconds
# [fir_lowpass_filter] cutoff = 3000 Hz
# [fir_lowpass_filter] order = 7 (bez2018model IHC filter)
# [cochlea] resampled subbands from 20000 Hz to 10000 Hz with filter: {'cutoff': 3000, 'fir_dur': 0.05, 'ihc_filter': True, 'order': 7}
# [cochlea] half-wave rectified resampled subbands
# [cochlea] incorporated sigmoid_rate_level_function: {'dynamic_range': [20.0, 40.0, 80.0], 'dynamic_range_interval': 0.95, 'envelope_mode': True, 'rate_max': [250.0, 250.0, 250.0], 'rate_spont': [0.0, 0.0, 0.0], 'threshold': [0.0, 12.0, 28.0]}
# [cochlea] inferring `sr=10000.0` for spike_generator_binomial
# [cochlea] incorporated spike_generator_binomial: {'mode': 'approx', 'n_per_channel': [384, 160, 96], 'sr': 10000.0}
# [cochlea] inferring `sr=10000.0` for autocorrelation_correlogram
# [cochlea] incorporated autocorrelation_correlogram: {'dur_frame': 0.05, 'overlap': 0.5, 'one_sided': True, 'concat_axis': None, 'sr': 10000.0}
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 40000)]           0
#
#  sequential_8 (Sequential)   (None, 50, 20000, 3)      0
#
# =================================================================
# Total params: 0 (0.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
"""
Load stimuli on which to evaluate model
"""

fn_stim = "stimuli/spkr_word_recognition/evaluation/speech_in_synthetic_textures/stim.hdf5"
with h5py.File(fn_stim, "r") as f:
    batch_size = 8
    idx0 = 0
    indexes = slice(idx0, idx0 + batch_size)
    y = f["signal"][indexes]
    print(f"Batch of example inputs: {y.shape=} {y.dtype=}")
    for k in f.keys():
        if f[k].ndim == 1:
            print("|__", k, f[k].dtype, f[k][indexes])
# Out:
# Batch of example inputs: y.shape=(8, 40000) y.dtype=dtype('float32')
# |__ dur float64 [2. 2. 2. 2. 2. 2. 2. 2.]
# |__ index_example int64 [0 1 2 3 4 5 6 7]
# |__ index_foreground int64 [0 1 2 3 4 5 6 7]
# |__ index_texture int64 [0 0 0 0 0 0 0 0]
# |__ label_speaker_int int64 [204 279 225 287 364 364 263 265]
# |__ label_word_int int64 [ 3  5  7  8 10 11 13 14]
# |__ snr int64 [-3 -3 -3 -3 -3 -3 -3 -3]
# |__ sr int64 [20000 20000 20000 20000 20000 20000 20000 20000]

# %%
# """
# Evaluate model on example stimuli
# """

# out = model(y)

# print("Model outputs (softmax cross entropy logits):")
# for k, v in out.items():
#     print("|__", k, v.dtype, v.shape)

# print("Model outputs (class label predictions):")
# for k, v in out.items():
#     print("|__", k, np.argmax(v, axis=1))

# %%
nervegram = model(y)
nervegram.shape
# Out:
# TensorShape([8, 50, 20000, 3])

# %%
nervegram_to_plot = nervegram[2, :, :, 0].numpy()
waveform_to_plot = y[2]
cfs = util_signal.erbspace(60.0, 8000.0, 50)
sr = 20000
sr_nervegram = 10000

figsize = (12, 5)
nrows = 2
ncols = 3
gridspec_kw = {
    "wspace": 0.15,
    "hspace": 0.15,
    "width_ratios": [1, 14, 1],
    "height_ratios": [1, 6],
}
fig, ax_arr = plt.subplots(nrows=nrows, ncols=ncols, figsize=figsize, gridspec_kw=gridspec_kw)
util_figures.make_stimulus_summary_plot(
    ax_arr,
    ax_idx_waveform=1,
    ax_idx_spectrum=3,
    ax_idx_nervegram=4,
    ax_idx_excitation=5,
    waveform=waveform_to_plot,
    nervegram=nervegram_to_plot,
    sr_waveform=sr,
    sr_nervegram=sr_nervegram,
    cfs=cfs,
    tmin=0.0,
    tmax=0.05 * 5,
    interpolation="none")
plt.show()

# %%
list_dir_model = glob.glob("models/sound_localization/autocorr_???sided/simplified_IHC????/arch*")

for dir_model in list_dir_model:
    fn_config = os.path.join(dir_model, "config.json")
    with open(fn_config, "r") as f_config:
        CONFIG = json.load(f_config)
    CONFIG["kwargs_cochlea"]["kwargs_autocorrelation_correlogram"] = {
        "dur_frame": 0.05,
        "overlap": 0.5 if "onesided" in dir_model else 0.0,
        "one_sided": True if "onesided" in dir_model else False,
        "concat_axis": -1,
    }
    if "sound_localization" in dir_model:
        CONFIG["kwargs_dataset_from_tfrecords"]["features_to_exclude"] = [
            "nervegram_meanrates",
            "list_background_index_brir",
        ]
    with open(fn_config, "w") as f_config:
        json.dump(CONFIG, f_config, indent=4, sort_keys=True)
    print(f'"{dir_model}"')
# Out:
# "models/sound_localization/autocorr_onesided/simplified_IHC0050/arch01"
# "models/sound_localization/autocorr_onesided/simplified_IHC0050/arch02"
# "models/sound_localization/autocorr_onesided/simplified_IHC0050/arch03"
# "models/sound_localization/autocorr_onesided/simplified_IHC0050/arch04"
# "models/sound_localization/autocorr_onesided/simplified_IHC0050/arch05"
# "models/sound_localization/autocorr_onesided/simplified_IHC0050/arch06"
# "models/sound_localization/autocorr_onesided/simplified_IHC0050/arch07"
# "models/sound_localization/autocorr_onesided/simplified_IHC0050/arch08"
# "models/sound_localization/autocorr_onesided/simplified_IHC0050/arch09"
# "models/sound_localization/autocorr_onesided/simplified_IHC0050/arch10"
# "models/sound_localization/autocorr_onesided/simplified_IHC0320/arch01"
# "models/sound_localization/autocorr_onesided/simplified_IHC0320/arch02"
# "models/sound_localization/autocorr_onesided/simplified_IHC0320/arch03"
# "models/sound_localization/autocorr_onesided/simplified_IHC0320/arch04"
# "models/sound_localization/autocorr_onesided/simplified_IHC0320/arch05"
# "models/sound_localization/autocorr_onesided/simplified_IHC0320/arch06"
# "models/sound_localization/autocorr_onesided/simplified_IHC0320/arch07"
# "models/sound_localization/autocorr_onesided/simplified_IHC0320/arch08"
# "models/sound_localization/autocorr_onesided/simplified_IHC0320/arch09"
# "models/sound_localization/autocorr_onesided/simplified_IHC0320/arch10"
# "models/sound_localization/autocorr_onesided/simplified_IHC1000/arch01"
# "models/sound_localization/autocorr_onesided/simplified_IHC1000/arch02"
# "models/sound_localization/autocorr_onesided/simplified_IHC1000/arch03"
# "models/sound_localization/autocorr_onesided/simplified_IHC1000/arch04"
# "models/sound_localization/autocorr_onesided/simplified_IHC1000/arch05"
# "models/sound_localization/autocorr_onesided/simplified_IHC1000/arch06"
# "models/sound_localization/autocorr_onesided/simplified_IHC1000/arch07"
# "models/sound_localization/autocorr_onesided/simplified_IHC1000/arch08"
# "models/sound_localization/autocorr_onesided/simplified_IHC1000/arch09"
# "models/sound_localization/autocorr_onesided/simplified_IHC1000/arch10"
# "models/sound_localization/autocorr_onesided/simplified_IHC3000/arch01"
# "models/sound_localization/autocorr_onesided/simplified_IHC3000/arch02"
# "models/sound_localization/autocorr_onesided/simplified_IHC3000/arch03"
# "models/sound_localization/autocorr_onesided/simplified_IHC3000/arch04"
# "models/sound_localization/autocorr_onesided/simplified_IHC3000/arch05"
# "models/sound_localization/autocorr_onesided/simplified_IHC3000/arch06"
# "models/sound_localization/autocorr_onesided/simplified_IHC3000/arch07"
# "models/sound_localization/autocorr_onesided/simplified_IHC3000/arch08"
# "models/sound_localization/autocorr_onesided/simplified_IHC3000/arch09"
# "models/sound_localization/autocorr_onesided/simplified_IHC3000/arch10"
# "models/sound_localization/autocorr_twosided/simplified_IHC0050/arch01"
# "models/sound_localization/autocorr_twosided/simplified_IHC0050/arch02"
# "models/sound_localization/autocorr_twosided/simplified_IHC0050/arch03"
# "models/sound_localization/autocorr_twosided/simplified_IHC0050/arch04"
# "models/sound_localization/autocorr_twosided/simplified_IHC0050/arch05"
# "models/sound_localization/autocorr_twosided/simplified_IHC0050/arch06"
# "models/sound_localization/autocorr_twosided/simplified_IHC0050/arch07"
# "models/sound_localization/autocorr_twosided/simplified_IHC0050/arch08"
# "models/sound_localization/autocorr_twosided/simplified_IHC0050/arch09"
# "models/sound_localization/autocorr_twosided/simplified_IHC0050/arch10"
# "models/sound_localization/autocorr_twosided/simplified_IHC0320/arch01"
# "models/sound_localization/autocorr_twosided/simplified_IHC0320/arch02"
# "models/sound_localization/autocorr_twosided/simplified_IHC0320/arch03"
# "models/sound_localization/autocorr_twosided/simplified_IHC0320/arch04"
# "models/sound_localization/autocorr_twosided/simplified_IHC0320/arch05"
# "models/sound_localization/autocorr_twosided/simplified_IHC0320/arch06"
# "models/sound_localization/autocorr_twosided/simplified_IHC0320/arch07"
# "models/sound_localization/autocorr_twosided/simplified_IHC0320/arch08"
# "models/sound_localization/autocorr_twosided/simplified_IHC0320/arch09"
# "models/sound_localization/autocorr_twosided/simplified_IHC0320/arch10"
# "models/sound_localization/autocorr_twosided/simplified_IHC1000/arch01"
# "models/sound_localization/autocorr_twosided/simplified_IHC1000/arch02"
# "models/sound_localization/autocorr_twosided/simplified_IHC1000/arch03"
# "models/sound_localization/autocorr_twosided/simplified_IHC1000/arch04"
# "models/sound_localization/autocorr_twosided/simplified_IHC1000/arch05"
# "models/sound_localization/autocorr_twosided/simplified_IHC1000/arch06"
# "models/sound_localization/autocorr_twosided/simplified_IHC1000/arch07"
# "models/sound_localization/autocorr_twosided/simplified_IHC1000/arch08"
# "models/sound_localization/autocorr_twosided/simplified_IHC1000/arch09"
# "models/sound_localization/autocorr_twosided/simplified_IHC1000/arch10"
# "models/sound_localization/autocorr_twosided/simplified_IHC3000/arch01"
# "models/sound_localization/autocorr_twosided/simplified_IHC3000/arch02"
# "models/sound_localization/autocorr_twosided/simplified_IHC3000/arch03"
# "models/sound_localization/autocorr_twosided/simplified_IHC3000/arch04"
# "models/sound_localization/autocorr_twosided/simplified_IHC3000/arch05"
# "models/sound_localization/autocorr_twosided/simplified_IHC3000/arch06"
# "models/sound_localization/autocorr_twosided/simplified_IHC3000/arch07"
# "models/sound_localization/autocorr_twosided/simplified_IHC3000/arch08"
# "models/sound_localization/autocorr_twosided/simplified_IHC3000/arch09"
# "models/sound_localization/autocorr_twosided/simplified_IHC3000/arch10"

# %%
import os
import sys
import copy
import glob
import h5py
import json

import util
import util_bez2018model
import util_tfrecords


BASE_CONFIG = {
    'examples_per_tfrecord_fin': 100000,
    'examples_per_tfrecord_tmp': 2000,
    'compression_type': 'GZIP',
    'disp_step': 100,
    'kwargs_ExampleProcessor': {
        'kwargs_nervegram': {
            'nervegram_dur': None,
            'nervegram_dtype': 'float16',
            'nervegram_fs': 10e3,
            'buffer_start_dur': 0.0,
            'buffer_end_dur': 0.0,
            'pin_fs': 100e3,
            'pin_dBSPL_flag': 0,
            'pin_dBSPL': None,
            'species': 2,
            'bandwidth_scale_factor': 1.0,
            'cf_list': None,
            'num_cf': 1,
            'min_cf': 125,
            'max_cf': 8e3,
            'max_spikes_per_train': 1000,
            'num_spike_trains': 1,
            'cohc': 1.0,
            'cihc': 1.0,
            'IhcLowPass_cutoff': 3000,
            'IhcLowPass_order': 7,
            'spont': [70.0],
            'noiseType': 1,
            'implnt': 0,
            'tabs': 6e-4,
            'trel': 6e-4,
            'synapseMode': 0,
            'random_seed': None,
            'return_vihcs': False,
            'return_meanrates': True,
            'return_spike_times': False,
            'return_spike_tensor_sparse': False,
            'return_spike_tensor_dense': False,
            'nervegram_spike_tensor_fs': 100e3,
            'squeeze_spont_dim': True,
            'squeeze_channel_dim': True,
        },
        'key_signal_fs': '/sources/signal/sr',
        'key_signal': '/stimuli/signal',
        'key_noise': None,
        'key_snr': None,
        'key_dbspl': None,
        'range_snr': None,
        'range_dbspl': [30.0, 90.0],
        'list_keys_to_copy': [
            ["/augment_STRAIGHT_f0_shift", "augment_STRAIGHT_f0_shift"],
            ["/augment_STRAIGHT_whisper", "augment_STRAIGHT_whisper"],
            ["/sources/noise/labels_binary_via_int", "label_audioset_multihot"],
            ["/sources/signal/speaker_int", "label_speaker_int"],
            ["/sources/signal/word_int", "label_word_int"],
            ['/sources/noise/snr', 'snr'],
        ],
        'list_keys_to_ignore': [
            'pin'
        ],
    }
}

list_dir_stim = [
    'stimuli/spkr_word_recognition/optimization/train',
    'stimuli/spkr_word_recognition/optimization/valid',
    'stimuli/spkr_word_recognition/evaluation/hopkins_moore_2009',
    'stimuli/spkr_word_recognition/evaluation/human_experiment_v00_foreground60dbspl',
    'stimuli/spkr_word_recognition/evaluation/human_experiment_v00_inharmonic_foreground60dbspl',
    'stimuli/spkr_word_recognition/evaluation/pitch_altered_v00',
    'stimuli/spkr_word_recognition/evaluation/speech_in_synthetic_textures',
]

for dir_stim in list_dir_stim:
    fn_src = glob.glob(os.path.join(dir_stim, '*.hdf5'))[0]
    CONFIG = copy.deepcopy(BASE_CONFIG)
    print('\n' + fn_src)
    if 'evaluation' in fn_src:
        CONFIG['kwargs_ExampleProcessor']['key_signal'] = 'signal'
        CONFIG['kwargs_ExampleProcessor']['key_signal_fs'] = 'sr'
        CONFIG['kwargs_ExampleProcessor']['range_dbspl'] = None
        CONFIG['kwargs_ExampleProcessor']['list_keys_to_copy'] = []
        with h5py.File(fn_src, 'r') as f_src:
            for k in util.get_hdf5_dataset_key_list(f_src):
                skip_list = [
                    'foreground_wav',
                    'foreground_wav_clip_pos',
                    'background_wav',
                    'background_wav_clip_pos',
                    'signal',
                    'background_signal',
                    'foreground_signal',
                ]
                if (k not in skip_list) and (f_src[k].shape[0] == f_src['signal'].shape[0]):
                    CONFIG['kwargs_ExampleProcessor']['list_keys_to_copy'].append(k)
                    assert len(f_src[k].shape) == 1

    dir_nervegram = os.path.join(dir_stim, 'tfrecords_simplified')
    fn_config = os.path.join(dir_nervegram, 'config.json')
    if not os.path.exists(dir_nervegram):
        os.mkdir(dir_nervegram)
        print(dir_nervegram)
    example_processor = util_bez2018model.ExampleProcessor(
        fn_src,
        idx_start=0,
        idx_end=100,
        random_seed=0,
        **CONFIG['kwargs_ExampleProcessor'])
    example = example_processor.process_example(0)
    feature_description, bytes_description = util_tfrecords.get_description_from_example(example)
    example_processor.close()
    CONFIG['feature_description'] = feature_description
    CONFIG['bytes_description'] = bytes_description
    util_bez2018model.write_config(dir_nervegram, CONFIG)
# Out:
# stimuli/spkr_word_recognition/optimization/train/JSIN_all__run_000_DZKGBOFKNVV2SVR5ZNV7KC5TRMD6P5ZJ.hdf5
# ###### EXAMPLE STRUCTURE ######
# ## augment_STRAIGHT_f0_shift float32 () -1.0
# ## augment_STRAIGHT_whisper float32 () 0.0
# ## dbspl float64 () 62.92881023563949
# ## label_audioset_multihot int64 (517,) 4136
# ## label_speaker_int int64 () 385
# ## label_word_int int64 () 28
# ## nervegram_meanrates float16 (1, 20000, 1) 40000
# ## signal float32 (40000,) 160000
# ## signal_fs int64 () 20000
# ## snr float64 () 2.0
# ###### EXAMPLE STRUCTURE ######
# [WROTE CONFIG] stimuli/spkr_word_recognition/optimization/train/tfrecords_simplified/config_feature_description.pkl
# [WROTE CONFIG] stimuli/spkr_word_recognition/optimization/train/tfrecords_simplified/config_bytes_description.pkl
# [WROTE CONFIG] stimuli/spkr_word_recognition/optimization/train/tfrecords_simplified/config.json
#
# stimuli/spkr_word_recognition/optimization/valid/JSIN_all__run_000_RQTTZB4C3TJJVLJUWDV72TYMC7S4MNHH.hdf5
# ###### EXAMPLE STRUCTURE ######
# ## augment_STRAIGHT_f0_shift float32 () -1.0
# ## augment_STRAIGHT_whisper float32 () 0.0
# ## dbspl float64 () 62.92881023563949
# ## label_audioset_multihot int64 (517,) 4136
# ## label_speaker_int int64 () 166
# ## label_word_int int64 () 577
# ## nervegram_meanrates float16 (1, 20000, 1) 40000
# ## signal float32 (40000,) 160000
# ## signal_fs int64 () 20000
# ## snr float64 () -2.0
# ###### EXAMPLE STRUCTURE ######
# [WROTE CONFIG] stimuli/spkr_word_recognition/optimization/valid/tfrecords_simplified/config_feature_description.pkl
# [WROTE CONFIG] stimuli/spkr_word_recognition/optimization/valid/tfrecords_simplified/config_bytes_description.pkl
# [WROTE CONFIG] stimuli/spkr_word_recognition/optimization/valid/tfrecords_simplified/config.json
#
# stimuli/spkr_word_recognition/evaluation/hopkins_moore_2009/stim.hdf5
# ###### EXAMPLE STRUCTURE ######
# ## background_condition int64 () 3
# ## background_index int64 () 0
# ## cutoff_channel int64 () -1
# ## cutoff_channel_freq float64 () nan
# ## foreground_dbspl float64 () 60.0
# ## foreground_index int64 () 0
# ## index int64 () 0
# ## inharmonic int64 () 0
# ## label_speaker_int int64 () 204
# ## label_word_int int64 () 3
# ## nervegram_meanrates float16 (1, 20000, 1) 40000
# ## signal float32 (40000,) 160000
# ## signal_fs int64 () 20000
# ## snr float64 () -24.0
# ## sr int64 () 20000
# ###### EXAMPLE STRUCTURE ######
# [WROTE CONFIG] stimuli/spkr_word_recognition/evaluation/hopkins_moore_2009/tfrecords_simplified/config_feature_description.pkl
# [WROTE CONFIG] stimuli/spkr_word_recognition/evaluation/hopkins_moore_2009/tfrecords_simplified/config_bytes_description.pkl
# [WROTE CONFIG] stimuli/spkr_word_recognition/evaluation/hopkins_moore_2009/tfrecords_simplified/config.json
#
# stimuli/spkr_word_recognition/evaluation/human_experiment_v00_foreground60dbspl/stim.hdf5
# ###### EXAMPLE STRUCTURE ######
# ## STRAIGHT_FLAG int64 () -1
# ## background_condition int64 () 0
# ## background_index int64 () 0
# ## dbspl float64 () 81.03817458293521
# ## foreground_dbspl float64 () 60.0
# ## foreground_index int64 () 0
# ## index int64 () 0
# ## label_speaker_int int64 () 204
# ## label_word_int int64 () 3
# ## nervegram_meanrates float16 (1, 20000, 1) 40000
# ## signal float32 (40000,) 160000
# ## signal_fs int64 () 20000
# ## snr float32 () -21.0
# ## sr int64 () 20000
# ###### EXAMPLE STRUCTURE ######
# [WROTE CONFIG] stimuli/spkr_word_recognition/evaluation/human_experiment_v00_foreground60dbspl/tfrecords_simplified/config_feature_description.pkl
# [WROTE CONFIG] stimuli/spkr_word_recognition/evaluation/human_experiment_v00_foreground60dbspl/tfrecords_simplified/config_bytes_description.pkl
# [WROTE CONFIG] stimuli/spkr_word_recognition/evaluation/human_experiment_v00_foreground60dbspl/tfrecords_simplified/config.json
#
# stimuli/spkr_word_recognition/evaluation/human_experiment_v00_inharmonic_foreground60dbspl/stim.hdf5
# ###### EXAMPLE STRUCTURE ######
# ## STRAIGHT_FLAG int64 () -1
# ## background_condition int64 () 0
# ## background_index int64 () 0
# ## dbspl float64 () 81.04887647042185
# ## foreground_dbspl float64 () 60.0
# ## foreground_index int64 () 0
# ## index int64 () 0
# ## inharmonic int64 () 1
# ## label_speaker_int int64 () 204
# ## label_word_int int64 () 3
# ## nervegram_meanrates float16 (1, 20000, 1) 40000
# ## signal float32 (40000,) 160000
# ## signal_fs int64 () 20000
# ## snr float32 () -21.0
# ## sr int64 () 20000
# ###### EXAMPLE STRUCTURE ######
# [WROTE CONFIG] stimuli/spkr_word_recognition/evaluation/human_experiment_v00_inharmonic_foreground60dbspl/tfrecords_simplified/config_feature_description.pkl
# [WROTE CONFIG] stimuli/spkr_word_recognition/evaluation/human_experiment_v00_inharmonic_foreground60dbspl/tfrecords_simplified/config_bytes_description.pkl
# [WROTE CONFIG] stimuli/spkr_word_recognition/evaluation/human_experiment_v00_inharmonic_foreground60dbspl/tfrecords_simplified/config.json
#
# stimuli/spkr_word_recognition/evaluation/pitch_altered_v00/stim.hdf5
# ###### EXAMPLE STRUCTURE ######
# ## f0_shift_in_semitones float64 () nan
# ## foreground_condition int64 () 0
# ## foreground_dbspl float64 () 60.0
# ## foreground_index int64 () 0
# ## index int64 () 0
# ## inharmonic int64 () 0
# ## label_speaker_int int64 () 204
# ## label_word_int int64 () 3
# ## nervegram_meanrates float16 (1, 20000, 1) 40000
# ## signal float32 (40000,) 160000
# ## signal_fs int64 () 20000
# ## snr float64 () inf
# ## sr int64 () 20000
# ## whispered int64 () 0
# ###### EXAMPLE STRUCTURE ######
# [WROTE CONFIG] stimuli/spkr_word_recognition/evaluation/pitch_altered_v00/tfrecords_simplified/config_feature_description.pkl
# [WROTE CONFIG] stimuli/spkr_word_recognition/evaluation/pitch_altered_v00/tfrecords_simplified/config_bytes_description.pkl
# [WROTE CONFIG] stimuli/spkr_word_recognition/evaluation/pitch_altered_v00/tfrecords_simplified/config.json
#
# stimuli/spkr_word_recognition/evaluation/speech_in_synthetic_textures/stim.hdf5
# ###### EXAMPLE STRUCTURE ######
# ## dur float64 () 2.0
# ## index_example int64 () 0
# ## index_foreground int64 () 0
# ## index_texture int64 () 0
# ## label_speaker_int int64 () 204
# ## label_word_int int64 () 3
# ## nervegram_meanrates float16 (1, 20000, 1) 40000
# ## signal float32 (40000,) 160000
# ## signal_fs int64 () 20000
# ## snr int64 () -3
# ## sr int64 () 20000
# ###### EXAMPLE STRUCTURE ######
# [WROTE CONFIG] stimuli/spkr_word_recognition/evaluation/speech_in_synthetic_textures/tfrecords_simplified/config_feature_description.pkl
# [WROTE CONFIG] stimuli/spkr_word_recognition/evaluation/speech_in_synthetic_textures/tfrecords_simplified/config_bytes_description.pkl
# [WROTE CONFIG] stimuli/spkr_word_recognition/evaluation/speech_in_synthetic_textures/tfrecords_simplified/config.json

# %%
BASE_CONFIG = {
    'examples_per_tfrecord_fin': 100000,
    'examples_per_tfrecord_tmp': 2000,
    'compression_type': 'GZIP',
    'disp_step': 100,
    'kwargs_ExampleProcessor': {
        'kwargs_nervegram': {
            'nervegram_dur': 1.3,
            'nervegram_dtype': 'float16',
            'nervegram_fs': 10e3,
            'buffer_start_dur': 0.07,
            'buffer_end_dur': 0.01,
            'pin_fs': 100e3,
            'pin_dBSPL_flag': 0,
            'pin_dBSPL': None,
            'species': 2,
            'bandwidth_scale_factor': 1.0,
            'cf_list': None,
            'num_cf': 1,
            'min_cf': 125,
            'max_cf': 16e3,
            'max_spikes_per_train': 1000,
            'num_spike_trains': 1,
            'cohc': 1.0,
            'cihc': 1.0,
            'IhcLowPass_cutoff': 3000,
            'IhcLowPass_order': 7,
            'spont': [70.0],
            'noiseType': 0,
            'implnt': 0,
            'tabs': 6e-4,
            'trel': 6e-4,
            'synapseMode': 0,
            'random_seed': None,
            'return_vihcs': False,
            'return_meanrates': True,
            'return_spike_times': False,
            'return_spike_tensor_sparse': False,
            'return_spike_tensor_dense': False,
            'nervegram_spike_tensor_fs': 100e3,
        },
        'key_signal_fs': 'sr',
        'key_signal': 'signal',
        'key_noise': None,
        'key_snr': None,
        'key_dbspl': None,
        'range_snr': None,
        'range_dbspl': None,
        'list_keys_to_copy': [],
        'list_keys_to_ignore': [
            'pin'
        ],
    }
}

list_dir_stim = [
    'stimuli/sound_localization/optimization/train',
    'stimuli/sound_localization/optimization/valid',
    'stimuli/sound_localization/evaluation/bandwidth_dependency',
    'stimuli/sound_localization/evaluation/itd_ild_weighting',
    'stimuli/sound_localization/evaluation/itd_threshold',
    'stimuli/sound_localization/evaluation/minimum_audible_angle_interpolated',
    'stimuli/sound_localization/evaluation/mp_spectral_cues',
    'stimuli/sound_localization/evaluation/new_ears',
    'stimuli/sound_localization/evaluation/precedence_effect_localization',
    'stimuli/sound_localization/evaluation/spectral_smoothing',
    'stimuli/sound_localization/evaluation/speech_in_noise_in_reverb_v04',
    'stimuli/sound_localization/evaluation/v01_eval_mit_bldg46room1004_tenoise',
]

for dir_stim in list_dir_stim:
    fn_src = glob.glob(os.path.join(dir_stim, '*.hdf5'))[0]
    CONFIG = copy.deepcopy(BASE_CONFIG)
    print('\n' + fn_src)
    with h5py.File(fn_src, 'r') as f_src:
        if f_src['signal'].shape[1] > 61740:
            CONFIG['kwargs_ExampleProcessor']['sample_start'] = int(0.28 * 44e3)
            CONFIG['kwargs_ExampleProcessor']['sample_end'] = int((0.28 + 1.40) * 44e3)
            CONFIG['kwargs_ExampleProcessor']['kwargs_nervegram']['nervegram_dur'] = 1.3
        elif f_src['signal'].shape[1] == 44100:
            CONFIG['kwargs_ExampleProcessor']['kwargs_nervegram']['nervegram_dur'] = 1.0
        for k in util.get_hdf5_dataset_key_list(f_src):
            skip_list = [
                'foreground_wav',
                'foreground_wav_clip_pos',
                'background_wav',
                'background_wav_clip_pos',
                'signal',
                'background_signal',
                'foreground_signal',
            ]
            if (k not in skip_list) and (f_src[k].shape[0] == f_src['signal'].shape[0]):
                CONFIG['kwargs_ExampleProcessor']['list_keys_to_copy'].append(k)
                assert len(f_src[k].shape) == 1

        dir_nervegram = os.path.join(dir_stim, 'tfrecords_simplified')
        fn_config = os.path.join(dir_nervegram, 'config.json')
        if not os.path.exists(dir_nervegram):
            os.mkdir(dir_nervegram)
            print(dir_nervegram)
        example_processor = util_bez2018model.ExampleProcessor(
            fn_src,
            idx_start=0,
            idx_end=100,
            random_seed=0,
            **CONFIG['kwargs_ExampleProcessor'])
        example = example_processor.process_example(0)
        feature_description, bytes_description = util_tfrecords.get_description_from_example(example)
        example_processor.close()
        CONFIG['feature_description'] = feature_description
        CONFIG['bytes_description'] = bytes_description
        util_bez2018model.write_config(dir_nervegram, CONFIG)
# Out:
# stimuli/sound_localization/optimization/train/stim_0000000_0009071.hdf5
# ###### EXAMPLE STRUCTURE ######
# ## dbspl float32 () 62.92881
# ## flag_complete int64 () 1
# ## foreground_azim int64 () 80
# ## foreground_dist float32 () 1.4
# ## foreground_elev int64 () 20
# ## foreground_index_brir int64 () 182
# ## index int64 () 0
# ## index_background int64 () 26281
# ## index_foreground int64 () 4908
# ## index_room int64 () 1484
# ## len_list_background_index_brir int64 () 7
# ## list_background_index_brir int64 (7,) [1017  229   70 1514 1153  510  631]
# ## n_loc_background int64 () 7
# ## n_loc_foreground int64 () 1
# ## nervegram_meanrates float16 (1, 13000, 1, 2) 52000
# ## signal float32 (57330, 2) 458640
# ## signal_fs int64 () 44100
# ## snr float32 () 2.3158484
# ## split_int int64 () 0
# ## sr int64 () 44100
# ###### EXAMPLE STRUCTURE ######
# [WROTE CONFIG] stimuli/sound_localization/optimization/train/tfrecords_simplified/config_feature_description.pkl
# [WROTE CONFIG] stimuli/sound_localization/optimization/train/tfrecords_simplified/config_bytes_description.pkl
# [WROTE CONFIG] stimuli/sound_localization/optimization/train/tfrecords_simplified/config.json
#
# stimuli/sound_localization/optimization/valid/stim_0000000_0010079.hdf5
# ###### EXAMPLE STRUCTURE ######
# ## dbspl float32 () 62.92881
# ## flag_complete int64 () 1
# ## foreground_azim int64 () 245
# ## foreground_dist float32 () 1.7460225
# ## foreground_elev int64 () 30
# ## foreground_index_brir int64 () 1338
# ## index int64 () 0
# ## index_background int64 () 968
# ## index_foreground int64 () 15325
# ## index_room int64 () 1811
# ## len_list_background_index_brir int64 () 11
# ## list_background_index_brir int64 (11,) 88
# ## n_loc_background int64 () 11
# ## n_loc_foreground int64 () 1
# ## nervegram_meanrates float16 (1, 13000, 1, 2) 52000
# ## signal float32 (57330, 2) 458640
# ## signal_fs int64 () 44100
# ## snr float32 () 0.156971
# ## split_int int64 () 1
# ## sr int64 () 44100
# ###### EXAMPLE STRUCTURE ######
# [WROTE CONFIG] stimuli/sound_localization/optimization/valid/tfrecords_simplified/config_feature_description.pkl
# [WROTE CONFIG] stimuli/sound_localization/optimization/valid/tfrecords_simplified/config_bytes_description.pkl
# [WROTE CONFIG] stimuli/sound_localization/optimization/valid/tfrecords_simplified/config.json
#
# stimuli/sound_localization/evaluation/bandwidth_dependency/stim.hdf5
# ###### EXAMPLE STRUCTURE ######
# ## bandwidth float64 () 0.0
# ## cutoff_high float64 () 210.22410381342863
# ## cutoff_low float64 () 210.22410381342863
# ## dbspl float64 () 53.01030010587388
# ## f float64 () 210.22410381342863
# ## f_ref int64 () 250
# ## foreground_azimuth int64 () 0
# ## foreground_elevation int64 () 0
# ## index int64 () 0
# ## index_brir int64 () 4
# ## index_room int64 () 0
# ## nervegram_meanrates float16 (1, 10000, 1, 2) 40000
# ## signal float32 (44100, 2) 352800
# ## signal_fs int64 () 44100
# ## sr int64 () 44100
# ###### EXAMPLE STRUCTURE ######
# [WROTE CONFIG] stimuli/sound_localization/evaluation/bandwidth_dependency/tfrecords_simplified/config_feature_description.pkl
# [WROTE CONFIG] stimuli/sound_localization/evaluation/bandwidth_dependency/tfrecords_simplified/config_bytes_description.pkl
# [WROTE CONFIG] stimuli/sound_localization/evaluation/bandwidth_dependency/tfrecords_simplified/config.json
#
# stimuli/sound_localization/evaluation/itd_ild_weighting/stim.hdf5
# ###### EXAMPLE STRUCTURE ######
# ## dbspl float32 () 50.5111
# ## foreground_azimuth int64 () 0
# ## foreground_elevation int64 () 0
# ## idx int64 () 10
# ## ild int64 () 0
# ## index int64 () 0
# ## itd int64 () -14
# ## nervegram_meanrates float16 (1, 13000, 1, 2) 52000
# ## noise_high int64 () 16000
# ## noise_low int64 () 1000
# ## signal float32 (57330, 2) 458640
# ## signal_fs int64 () 44100
# ## sr int64 () 44100
# ## subject int64 () 999
# ###### EXAMPLE STRUCTURE ######
# [WROTE CONFIG] stimuli/sound_localization/evaluation/itd_ild_weighting/tfrecords_simplified/config_feature_description.pkl
# [WROTE CONFIG] stimuli/sound_localization/evaluation/itd_ild_weighting/tfrecords_simplified/config_bytes_description.pkl
# [WROTE CONFIG] stimuli/sound_localization/evaluation/itd_ild_weighting/tfrecords_simplified/config.json
#
# stimuli/sound_localization/evaluation/itd_threshold/stim.hdf5
# ###### EXAMPLE STRUCTURE ######
# ## dbspl float64 () 70.0
# ## dur float64 () 0.5
# ## dur_padded float64 () 1.3
# ## f float64 () 250.0
# ## foreground_azim float64 () 0.0
# ## foreground_elev float64 () 0.0
# ## itd float64 () -0.00016
# ## nervegram_meanrates float16 (1, 13000, 1, 2) 52000
# ## rise float64 () 0.1
# ## signal float32 (57330, 2) 458640
# ## signal_fs int64 () 44100
# ## sr int64 () 44100
# ###### EXAMPLE STRUCTURE ######
# [WROTE CONFIG] stimuli/sound_localization/evaluation/itd_threshold/tfrecords_simplified/config_feature_description.pkl
# [WROTE CONFIG] stimuli/sound_localization/evaluation/itd_threshold/tfrecords_simplified/config_bytes_description.pkl
# [WROTE CONFIG] stimuli/sound_localization/evaluation/itd_threshold/tfrecords_simplified/config.json
#
# stimuli/sound_localization/evaluation/minimum_audible_angle_interpolated/stim.hdf5
# ###### EXAMPLE STRUCTURE ######
# ## dbspl float64 () 59.99999999999992
# ## f float64 () 229.2510108011678
# ## f_ref float64 () 250.0
# ## foreground_azimuth float64 () -90.0
# ## foreground_elevation int64 () 0
# ## index int64 () 0
# ## index_brir int64 () -1
# ## index_room int64 () 0
# ## nervegram_meanrates float16 (1, 10000, 1, 2) 40000
# ## signal float32 (44100, 2) 352800
# ## signal_fs int64 () 44100
# ## sr int64 () 44100
# ###### EXAMPLE STRUCTURE ######
# [WROTE CONFIG] stimuli/sound_localization/evaluation/minimum_audible_angle_interpolated/tfrecords_simplified/config_feature_description.pkl
# [WROTE CONFIG] stimuli/sound_localization/evaluation/minimum_audible_angle_interpolated/tfrecords_simplified/config_bytes_description.pkl
# [WROTE CONFIG] stimuli/sound_localization/evaluation/minimum_audible_angle_interpolated/tfrecords_simplified/config.json
#
# stimuli/sound_localization/evaluation/mp_spectral_cues/stim.hdf5
# ###### EXAMPLE STRUCTURE ######
# ## dbspl float32 () 57.53602
# ## foreground_azimuth int64 () 0
# ## foreground_elevation int64 () 0
# ## idx int64 () 10
# ## index int64 () 0
# ## loc_idx int64 () 0
# ## nervegram_meanrates float16 (1, 13000, 1, 2) 52000
# ## noise_high int64 () 20000
# ## noise_low int64 () 10000
# ## signal float32 (57330, 2) 458640
# ## signal_fs int64 () 44100
# ## sr int64 () 44100
# ###### EXAMPLE STRUCTURE ######
# [WROTE CONFIG] stimuli/sound_localization/evaluation/mp_spectral_cues/tfrecords_simplified/config_feature_description.pkl
# [WROTE CONFIG] stimuli/sound_localization/evaluation/mp_spectral_cues/tfrecords_simplified/config_bytes_description.pkl
# [WROTE CONFIG] stimuli/sound_localization/evaluation/mp_spectral_cues/tfrecords_simplified/config.json
#
# stimuli/sound_localization/evaluation/new_ears/stim.hdf5
# ###### EXAMPLE STRUCTURE ######
# ## dbspl float32 () 61.780582
# ## foreground_azimuth int64 () 0
# ## foreground_elevation int64 () 0
# ## idx int64 () 10
# ## index int64 () 0
# ## nervegram_meanrates float16 (1, 13000, 1, 2) 52000
# ## noise_high int64 () 20000
# ## noise_low int64 () 20
# ## signal float32 (57330, 2) 458640
# ## signal_fs int64 () 44100
# ## sr int64 () 44100
# ## subject int64 () 3
# ###### EXAMPLE STRUCTURE ######
# [WROTE CONFIG] stimuli/sound_localization/evaluation/new_ears/tfrecords_simplified/config_feature_description.pkl
# [WROTE CONFIG] stimuli/sound_localization/evaluation/new_ears/tfrecords_simplified/config_bytes_description.pkl
# [WROTE CONFIG] stimuli/sound_localization/evaluation/new_ears/tfrecords_simplified/config.json
#
# stimuli/sound_localization/evaluation/precedence_effect_localization/stim.hdf5
# ###### EXAMPLE STRUCTURE ######
# ## azim_lag int64 () 300
# ## azim_lead int64 () 300
# ## dbspl float64 () 48.748642597675904
# ## delay float64 () inf
# ## elev_lag int64 () 0
# ## elev_lead int64 () 0
# ## index int64 () 0
# ## index_brir_lag int64 () 664
# ## index_brir_lead int64 () 664
# ## index_room int64 () 0
# ## nervegram_meanrates float16 (1, 10000, 1, 2) 40000
# ## signal float32 (44100, 2) 352800
# ## signal_fs int64 () 44100
# ## sr int64 () 44100
# ###### EXAMPLE STRUCTURE ######
# [WROTE CONFIG] stimuli/sound_localization/evaluation/precedence_effect_localization/tfrecords_simplified/config_feature_description.pkl
# [WROTE CONFIG] stimuli/sound_localization/evaluation/precedence_effect_localization/tfrecords_simplified/config_bytes_description.pkl
# [WROTE CONFIG] stimuli/sound_localization/evaluation/precedence_effect_localization/tfrecords_simplified/config.json
#
# stimuli/sound_localization/evaluation/spectral_smoothing/stim.hdf5
# ###### EXAMPLE STRUCTURE ######
# ## dbspl float32 () 61.67741
# ## foreground_azimuth int64 () 0
# ## foreground_elevation int64 () 0
# ## idx int64 () 10
# ## index int64 () 0
# ## nervegram_meanrates float16 (1, 13000, 1, 2) 52000
# ## noise_high int64 () 20000
# ## noise_low int64 () 20
# ## signal float32 (57330, 2) 458640
# ## signal_fs int64 () 44100
# ## smoothed int64 () 128
# ## sr int64 () 44100
# ###### EXAMPLE STRUCTURE ######
# [WROTE CONFIG] stimuli/sound_localization/evaluation/spectral_smoothing/tfrecords_simplified/config_feature_description.pkl
# [WROTE CONFIG] stimuli/sound_localization/evaluation/spectral_smoothing/tfrecords_simplified/config_bytes_description.pkl
# [WROTE CONFIG] stimuli/sound_localization/evaluation/spectral_smoothing/tfrecords_simplified/config.json
#
# stimuli/sound_localization/evaluation/speech_in_noise_in_reverb_v04/stim.hdf5
# ###### EXAMPLE STRUCTURE ######
# ## foreground_azim float64 () 80.0
# ## foreground_dist float64 () 2.0
# ## foreground_elev float64 () 0.0
# ## index int64 () 0
# ## index_brir int64 () 16
# ## index_room int64 () 0
# ## label_speaker_int int64 () 204
# ## label_word_int int64 () 3
# ## nervegram_meanrates float16 (1, 13000, 1, 2) 52000
# ## signal float32 (57330, 2) 458640
# ## signal_fs int64 () 44100
# ## snr float32 () -24.0
# ## sr int64 () 44100
# ###### EXAMPLE STRUCTURE ######
# [WROTE CONFIG] stimuli/sound_localization/evaluation/speech_in_noise_in_reverb_v04/tfrecords_simplified/config_feature_description.pkl
# [WROTE CONFIG] stimuli/sound_localization/evaluation/speech_in_noise_in_reverb_v04/tfrecords_simplified/config_bytes_description.pkl
# [WROTE CONFIG] stimuli/sound_localization/evaluation/speech_in_noise_in_reverb_v04/tfrecords_simplified/config.json
#
# stimuli/sound_localization/evaluation/v01_eval_mit_bldg46room1004_tenoise/stim_000000_026220.hdf5
# ###### EXAMPLE STRUCTURE ######
# ## channels int64 () 1
# ## clip_dur_in_s float64 () 1.0
# ## clip_end_in_s float64 () 1.0
# ## clip_start_in_s int64 () 0
# ## dbspl float64 () 73.77733307423323
# ## foreground_azim int64 () 0
# ## foreground_dbspl float64 () 60.0
# ## foreground_dist float64 () 2.0
# ## foreground_elev int64 () 0
# ## foreground_index_brir int64 () 506
# ## index int64 () 0
# ## index_foreground int64 () 0
# ## index_room int64 () 0
# ## label_gise_int int64 () 0
# ## n_loc_background int64 () 9
# ## n_loc_foreground int64 () 1
# ## nervegram_meanrates float16 (1, 10000, 1, 2) 40000
# ## segment_id int64 () 119023
# ## signal float32 (44100, 2) 352800
# ## signal_fs int64 () 44100
# ## snr float64 () -13.6
# ## split_int int64 () 2
# ## sr int64 () 44100
# ## total_file_duration_in_s float64 () 1.0
# ###### EXAMPLE STRUCTURE ######
# [WROTE CONFIG] stimuli/sound_localization/evaluation/v01_eval_mit_bldg46room1004_tenoise/tfrecords_simplified/config_feature_description.pkl
# [WROTE CONFIG] stimuli/sound_localization/evaluation/v01_eval_mit_bldg46room1004_tenoise/tfrecords_simplified/config_bytes_description.pkl
# [WROTE CONFIG] stimuli/sound_localization/evaluation/v01_eval_mit_bldg46room1004_tenoise/tfrecords_simplified/config.json
